# %%
# !pip install transformers==4.46.1 tokenizers==0.20.2 accelerate==1.0.1 peft==0.13.2 jinja2==3.1.2 fuzzywuzzy==0.18.0 python-Levenshtein==0.25.1 networkx==3.0

# %%
# !pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu118

# %%
# !pip install pandas

# %%
# !git clone -b step1-hybrid-retrieval https://github.com/WldEJackal/CodeFuse-CGM.git

# %%
import os
from huggingface_hub import snapshot_download

OUT_DIR = "/teamspace/studios/this_studio/CodeFuse-CGM/retriever/subgraph"
os.makedirs(OUT_DIR, exist_ok=True)

snapshot_download(
    repo_id="Bouelez/serialize_subgraph",
    repo_type="dataset",
    local_dir=OUT_DIR,
    local_dir_use_symlinks=False, # download only the subset folder
)

# %%
# !pip install --upgrade "vllm>=0.8.5"

# %%
# !pip install --upgrade --force-reinstall "numpy<2.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 116.5 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.4
#     Uninstalling numpy-2.4.4:
#       Successfully uninstalled numpy-2.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !python /teamspace/studios/this_studio/CodeFuse-CGM/reranker/reranker.py --stage_1_k 10 --stage_2_k 5
# Out:
# INFO 04-03 21:36:00 [utils.py:233] non-default args: {'max_model_len': 32768, 'disable_log_stats': True, 'model': 'Qwen/Qwen2.5-Coder-32B-Instruct'}
# INFO 04-03 21:36:01 [model.py:533] Resolved architecture: Qwen2ForCausalLM
# INFO 04-03 21:36:01 [model.py:1582] Using max model len 32768
# INFO 04-03 21:36:01 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=16384.
# INFO 04-03 21:36:01 [vllm.py:775] Asynchronous scheduling is enabled.
# ...

# %%
import shutil
shutil.make_archive("/teamspace/studios/this_studio/CodeFuse-CGM/reranker", "zip", "/teamspace/studios/this_studio/CodeFuse-CGM/reranker")
# Out:
# '/teamspace/studios/this_studio/CodeFuse-CGM/reranker.zip'
